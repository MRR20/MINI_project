# %% [markdown]
# <a href="https://colab.research.google.com/github/MRR20/PyNotebooks/blob/main/test_0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# MiniProject Test_0

# %%
import requests

company = "GOOG"
api_key = "COOFAIV9AV9SVV19"
url = f'https://www.alphavantage.co/query?function=TIME_SERIES_DAILY&outputsize=compact&symbol={company}&apikey={api_key}&datatype=csv'
r = requests.get(url)
data = r.text

print(data)
# Out:
# timestamp,open,high,low,close,volume
# 2024-07-26,168.7700,169.8400,165.8650,168.6800,25150116
# 2024-07-25,174.2500,175.2000,169.0500,169.1600,28967880
# 2024-07-24,175.3900,177.9500,173.5700,174.3700,31250683
# 2024-07-23,183.8400,185.2200,183.3300,183.6000,23772602
# 2024-07-22,182.3500,184.3000,181.9000,183.3500,16303896
# 2024-07-19,180.3700,181.9700,178.8600,179.3900,14485899
# 2024-07-18,183.5400,184.0500,178.2100,179.2200,17877197
# 2024-07-17,184.6800,185.2300,181.6200,182.6200,17376563
# 2024-07-16,188.9600,190.3400,185.1200,185.5000,12760102
# 2024-07-15,186.4900,189.9000,186.4900,188.1900,12186015
# 2024-07-12,186.9200,188.6900,186.1400,186.7800,14449113
# 2024-07-11,191.3400,192.4100,186.8200,187.3000,16451981
# 2024-07-10,190.7500,193.3100,190.6200,192.6600,12052906
# 2024-07-09,191.7500,192.8600,190.2300,190.4400,10224925
# 2024-07-08,191.3650,191.6791,189.3200,190.4800,12097611
# 2024-07-05,187.3200,192.2600,187.3200,191.9600,14303361
# 2024-07-03,186.3000,187.6200,185.3850,187.3900,7409106
# 2024-07-02,183.4700,186.9500,183.0600,186.6100,12555545
# 2024-07-01,184.4800,185.3400,182.7300,184.4900,11815862
# 2024-06-28,185.7200,186.5800,183.3250,183.4200,23032362
# 2024-06-27,185.6450,187.5000,185.4500,186.8600,13025656
# 2024-06-26,184.2000,185.9300,183.9900,185.3700,13375715
# 2024-06-25,181.1450,185.7500,181.1050,185.5800,18917734
# 2024-06-24,181.2800,182.0800,180.2300,180.7900,18198282
# 2024-06-21,178.4900,182.5117,178.0600,180.2600,59728019
# 2024-06-20,176.7100,178.7400,176.4600,177.7100,16753166
# 2024-06-18,178.7900,178.9100,175.6200,176.4500,15640257
# 2024-06-17,176.9800,179.9200,176.4900,178.7800,15272864
# 2024-06-14,175.8520,178.7300,175.8520,178.3700,12361571
# 2024-06-13,177.8400,178.5100,176.6600,176.7400,15956941
# 2024-06-12,179.7500,182.0800,177.7800,179.5600,18600421
# 2024-06-11,177.7200,178.3900,175.4400,178.1900,14402401
# 2024-06-10,176.4500,178.4700,174.3800,176.6300,17122247
# 2024-06-07,178.4600,179.4200,175.7900,175.9500,14716270
# 2024-06-06,177.4300,178.7100,177.2100,178.3500,14255818
# 2024-06-05,176.5350,177.9700,175.2900,177.0700,15233861
# 2024-06-04,174.4500,175.1900,173.2200,175.1300,14066602
# 2024-06-03,173.8800,175.8600,172.4500,174.4200,20742798
# 2024-05-31,173.4000,174.4200,170.9700,173.9600,28085151
# 2024-05-30,176.6900,176.6900,173.2300,173.5600,18844036
# 2024-05-29,176.8100,178.2300,176.2600,177.4000,15023847
# 2024-05-28,175.7400,178.5100,175.6800,178.0200,15655340
# 2024-05-24,176.5200,177.3044,175.2000,176.3300,11403560
# 2024-05-23,178.7800,179.9100,174.5400,175.0600,14928363
# 2024-05-22,178.4000,178.8520,176.7801,178.0000,16189404
# 2024-05-21,178.4000,179.8200,177.3100,179.5400,14706021
# 2024-05-20,177.3100,179.9500,177.2250,178.4600,17495122
# 2024-05-17,175.5500,177.4950,174.9800,177.2900,16546353
# 2024-05-16,174.6000,176.3400,174.0500,175.4300,17247311
# 2024-05-15,172.3000,174.0459,172.0300,173.8800,20958245
# 2024-05-14,171.5900,172.7800,170.4200,171.9300,18729463
# 2024-05-13,165.8470,170.9500,165.7600,170.9000,19648585
# 2024-05-10,169.6900,171.3400,167.9100,170.2900,18740458
# 2024-05-09,171.1500,172.4400,169.9300,171.5800,11937704
# 2024-05-08,170.7500,171.9092,170.5220,171.1600,14569858
# 2024-05-07,170.1200,173.4700,170.0000,172.9800,21102434
# 2024-05-06,169.2200,169.9000,167.8900,169.8300,15147906
# 2024-05-03,169.5400,169.8500,164.9800,168.9900,22767056
# 2024-05-02,166.6700,168.5300,165.6900,168.4600,17041119
# 2024-05-01,166.1800,168.8100,164.9000,165.5700,25223245
# 2024-04-30,167.3800,169.8700,164.5000,164.6400,29420755
# 2024-04-29,170.7700,171.3800,167.0600,167.9000,35914561
# 2024-04-26,175.9900,176.4200,171.4000,173.6900,56500787
# 2024-04-25,153.3600,158.2800,152.7680,157.9500,36197789
# 2024-04-24,159.0900,161.3900,158.8200,161.1000,19485694
# 2024-04-23,158.5900,160.4800,157.9650,159.9200,16115408
# 2024-04-22,156.0100,159.1850,155.6600,157.9500,17243870
# 2024-04-19,157.7500,157.9900,153.9100,155.7200,21479881
# 2024-04-18,156.9250,158.4850,156.2100,157.4600,14016065
# 2024-04-17,157.1900,158.6810,156.1350,156.8800,16237752
# 2024-04-16,155.6400,157.2300,155.0500,156.0000,15413201
# 2024-04-15,160.2800,160.8300,156.1500,156.3300,21140948
# 2024-04-12,159.4050,161.7000,158.6000,159.1900,16989765
# 2024-04-11,158.3400,161.1199,157.9300,160.7900,17841703
# 2024-04-10,157.8800,158.1600,156.2000,157.6600,16339174
# 2024-04-09,157.3500,159.8900,156.6400,158.1400,21435146
# 2024-04-08,154.0150,156.6550,153.9900,156.1400,16280924
# 2024-04-05,151.6800,154.8400,151.0810,153.9400,16212049
# 2024-04-04,155.0800,156.1800,151.8800,151.9400,23901697
# 2024-04-03,154.9200,156.5500,154.1321,156.3700,16984168
# 2024-04-02,154.7500,155.9900,153.4600,155.8700,17549140
# 2024-04-01,151.8300,157.0000,151.6500,156.5000,24416137
# 2024-03-28,152.0000,152.6700,151.3300,152.2600,21105628
# 2024-03-27,152.1450,152.6900,150.1300,151.9400,16621964
# 2024-03-26,151.2400,153.2000,151.0300,151.7000,19312694
# 2024-03-25,150.9500,151.4560,148.8000,151.1500,15114728
# 2024-03-22,150.2400,152.5600,150.0900,151.7700,19252925
# 2024-03-21,150.3200,151.3050,148.0101,148.7400,19843915
# 2024-03-20,148.7900,149.7600,147.6650,149.6800,17729996
# 2024-03-19,148.9800,149.6200,147.0100,147.9200,17748367
# 2024-03-18,149.3700,152.9300,148.1400,148.4800,47676689
# 2024-03-15,143.4100,144.3400,141.1301,142.1700,41039494
# 2024-03-14,142.3000,144.7300,141.4850,144.3400,35991108
# 2024-03-13,140.0600,142.1900,140.0100,140.7700,19589151
# 2024-03-12,138.2500,140.2800,138.2100,139.6200,18951920
# 2024-03-11,137.0700,139.9800,137.0700,138.9400,22462576
# 2024-03-08,135.0350,138.9850,134.8000,136.2900,26495160
# 2024-03-07,133.8900,135.8200,132.6600,135.2400,24107282
# 2024-03-06,134.2400,134.7400,131.9500,132.5600,23175200
# 2024-03-05,132.7400,134.0200,131.5500,133.7800,28447550

# %%
import pandas as pd
import requests
from io import StringIO
df = pd.read_csv(StringIO(data))

print(df.head())
print(len(df['close']))
# Out:
#     timestamp    open    high      low   close    volume
# 0  2024-07-26  168.77  169.84  165.865  168.68  25150116
# 1  2024-07-25  174.25  175.20  169.050  169.16  28967880
# 2  2024-07-24  175.39  177.95  173.570  174.37  31250683
# 3  2024-07-23  183.84  185.22  183.330  183.60  23772602
# 4  2024-07-22  182.35  184.30  181.900  183.35  16303896
# 100

# %%
from matplotlib import pyplot as plt
plt.plot(df['open'])
plt.plot(df['close'])
plt.show()

# %%
print(df['timestamp'])
# Out:
# 0     2024-07-26
# 1     2024-07-25
# 2     2024-07-24
# 3     2024-07-23
# 4     2024-07-22
#          ...
# 95    2024-03-11
# 96    2024-03-08
# 97    2024-03-07
# 98    2024-03-06
# 99    2024-03-05
# Name: timestamp, Length: 100, dtype: object

# %%
time_list=df['timestamp'].to_list()
print(time_list)
# Out:
# ['2024-07-26', '2024-07-25', '2024-07-24', '2024-07-23', '2024-07-22', '2024-07-19', '2024-07-18', '2024-07-17', '2024-07-16', '2024-07-15', '2024-07-12', '2024-07-11', '2024-07-10', '2024-07-09', '2024-07-08', '2024-07-05', '2024-07-03', '2024-07-02', '2024-07-01', '2024-06-28', '2024-06-27', '2024-06-26', '2024-06-25', '2024-06-24', '2024-06-21', '2024-06-20', '2024-06-18', '2024-06-17', '2024-06-14', '2024-06-13', '2024-06-12', '2024-06-11', '2024-06-10', '2024-06-07', '2024-06-06', '2024-06-05', '2024-06-04', '2024-06-03', '2024-05-31', '2024-05-30', '2024-05-29', '2024-05-28', '2024-05-24', '2024-05-23', '2024-05-22', '2024-05-21', '2024-05-20', '2024-05-17', '2024-05-16', '2024-05-15', '2024-05-14', '2024-05-13', '2024-05-10', '2024-05-09', '2024-05-08', '2024-05-07', '2024-05-06', '2024-05-03', '2024-05-02', '2024-05-01', '2024-04-30', '2024-04-29', '2024-04-26', '2024-04-25', '2024-04-24', '2024-04-23', '2024-04-22', '2024-04-19', '2024-04-18', '2024-04-17', '2024-04-16', '2024-04-15', '2024-04-12', '2024-04-11', '2024-04-10', '2024-04-09', '2024-04-08', '2024-04-05', '2024-04-04', '2024-04-03', '2024-04-02', '2024-04-01', '2024-03-28', '2024-03-27', '2024-03-26', '2024-03-25', '2024-03-22', '2024-03-21', '2024-03-20', '2024-03-19', '2024-03-18', '2024-03-15', '2024-03-14', '2024-03-13', '2024-03-12', '2024-03-11', '2024-03-08', '2024-03-07', '2024-03-06', '2024-03-05']

# %%
print(df['close'])
# Out:
# 0     168.68
# 1     169.16
# 2     174.37
# 3     183.60
# 4     183.35
#        ...
# 95    138.94
# 96    136.29
# 97    135.24
# 98    132.56
# 99    133.78
# Name: close, Length: 100, dtype: float64

# %%
close_list=df['close'].to_list()
print(close_list)
# Out:
# [168.68, 169.16, 174.37, 183.6, 183.35, 179.39, 179.22, 182.62, 185.5, 188.19, 186.78, 187.3, 192.66, 190.44, 190.48, 191.96, 187.39, 186.61, 184.49, 183.42, 186.86, 185.37, 185.58, 180.79, 180.26, 177.71, 176.45, 178.78, 178.37, 176.74, 179.56, 178.19, 176.63, 175.95, 178.35, 177.07, 175.13, 174.42, 173.96, 173.56, 177.4, 178.02, 176.33, 175.06, 178.0, 179.54, 178.46, 177.29, 175.43, 173.88, 171.93, 170.9, 170.29, 171.58, 171.16, 172.98, 169.83, 168.99, 168.46, 165.57, 164.64, 167.9, 173.69, 157.95, 161.1, 159.92, 157.95, 155.72, 157.46, 156.88, 156.0, 156.33, 159.19, 160.79, 157.66, 158.14, 156.14, 153.94, 151.94, 156.37, 155.87, 156.5, 152.26, 151.94, 151.7, 151.15, 151.77, 148.74, 149.68, 147.92, 148.48, 142.17, 144.34, 140.77, 139.62, 138.94, 136.29, 135.24, 132.56, 133.78]

# %%
import pandas as pd
import requests
from io import StringIO

ticker="GOOG"
#&tickers={ticker}
#&time_from=20240724T0000&time_to=20240724T2359
url = f'https://www.alphavantage.co/query?function=NEWS_SENTIMENT&topic=finance&apikey=COOFAIV9AV9SVV19'
r = requests.get(url)
data = r.json() # Parse the response as JSON

# Assuming the relevant data is in the 'feed' key
df = pd.DataFrame(data.get('feed', []))

#print(df)

print(df.head())
print(len(df['title']))
print(df['time_published'])
# Out:
#                                                title  \
# 0                                Before you continue
# 1                                Before you continue
# 2  Chinese EV maker Nio launches second-generatio...
# 3  AAVE founder issues health warning to crypto f...
# 4                                Before you continue
#
#                                                  url   time_published  \
# 0                       https://consent.google.com/m  20240728T043540
# 1                       https://consent.google.com/m  20240728T040351
# 2  https://www.scmp.com/business/china-business/a...  20240728T035756
# 3  https://cointelegraph.com/news/aave-founder-st...  20240728T034409
# 4                       https://consent.google.com/m  20240728T023217
#
#           authors                                            summary  \
# 0              []  Massive wildfire engulfs northern California, ...
# 1              []  Harris addresses herself an underdog, touts he...
# 2    [Daniel Ren]  The Nio Phone has enhanced technological capab...
# 3  [Ciaran Lyons]  AAVE founder Stani Kulechov says he "rarely" e...
# 4              []  Trump to campaign in Minnesota, a state that h...
#
#                                         banner_image  \
# 0                                               None
# 1                                               None
# 2  https://img.i-scmp.com/cdn-cgi/image/fit=conta...
# 3  https://images.cointelegraph.com/cdn-cgi/image...
# 4                                               None
#
#                      source category_within_source       source_domain  \
# 0         Business Standard              GoogleRSS  consent.google.com
# 1         Business Standard              GoogleRSS  consent.google.com
# 2  South China Morning Post              Companies        www.scmp.com
# 3             Cointelegraph                    n/a   cointelegraph.com
# 4         Business Standard              GoogleRSS  consent.google.com
#
#                                               topics  overall_sentiment_score  \
# 0  [{'topic': 'Technology', 'relevance_score': '1...                 0.086343
# 1  [{'topic': 'Technology', 'relevance_score': '1...                 0.086343
# 2                                                 []                 0.263018
# 3  [{'topic': 'Blockchain', 'relevance_score': '0...                -0.029365
# 4  [{'topic': 'Technology', 'relevance_score': '1...                 0.086343
#
#   overall_sentiment_label                                   ticker_sentiment
# 0                 Neutral  [{'ticker': 'GOOG', 'relevance_score': '0.2130...
# 1                 Neutral  [{'ticker': 'GOOG', 'relevance_score': '0.2130...
# 2        Somewhat-Bullish  [{'ticker': 'XIACY', 'relevance_score': '0.080...
# 3                 Neutral  [{'ticker': 'CRYPTO:AAVE', 'relevance_score': ...
# 4                 Neutral  [{'ticker': 'GOOG', 'relevance_score': '0.2130...
# 50
# 0     20240728T043540
# 1     20240728T040351
# 2     20240728T035756
# 3     20240728T034409
# 4     20240728T023217
# 5     20240728T023217
# 6     20240728T020526
# 7     20240728T020019
# 8     20240728T013000
# 9     20240728T011925
# 10    20240728T011748
# 11    20240728T011125
# 12    20240728T010000
# 13    20240728T010000
# 14    20240728T010000
# 15    20240728T010000
# 16    20240728T010000
# 17    20240728T004933
# 18    20240728T000023
# 19    20240727T230013
# 20    20240727T225315
# 21    20240727T224500
# 22    20240727T223600
# 23    20240727T223000
# 24    20240727T222700
# 25    20240727T222600
# 26    20240727T222000
# 27    20240727T221400
# 28    20240727T220800
# 29    20240727T220500
# 30    20240727T220200
# 31    20240727T220000
# 32    20240727T213000
# 33    20240727T211839
# 34    20240727T211800
# 35    20240727T210222
# 36    20240727T210000
# 37    20240727T205500
# 38    20240727T204400
# 39    20240727T203000
# 40    20240727T202725
# 41    20240727T201200
# 42    20240727T200000
# 43    20240727T194209
# 44    20240727T191643
# 45    20240727T184019
# 46    20240727T182655
# 47    20240727T181800
# 48    20240727T180700
# 49    20240727T180532
# Name: time_published, dtype: object

# %%
df['overall_sentiment_score'].head(), df['summary'].head()
# Out:
# (0    0.314531
#  1    0.144264
#  2    0.039067
#  3    0.541221
#  4   -0.057454
#  Name: overall_sentiment_score, dtype: float64,
#  0    WASHINGTON, July 24, 2024 ( GLOBE NEWSWIRE ) -...
#  1    Apple is reportedly working on a clamshell-sty...
#  2    CNBC's Jim Cramer looked at what caused Wednes...
#  3    Los Angeles, CA , July 24, 2024 ( GLOBE NEWSWI...
#  4    The device, called a 'Bitaxe,' successfully mi...
#  Name: summary, dtype: object)

# %%
df['summary'].head()
# Out:
# 0    WASHINGTON, July 24, 2024 ( GLOBE NEWSWIRE ) -...
# 1    Apple is reportedly working on a clamshell-sty...
# 2    CNBC's Jim Cramer looked at what caused Wednes...
# 3    Los Angeles, CA , July 24, 2024 ( GLOBE NEWSWI...
# 4    The device, called a 'Bitaxe,' successfully mi...
# Name: summary, dtype: object

# %%
df['url']
# Out:
# 0     https://www.benzinga.com/pressreleases/24/07/g...
# 1     https://www.scmp.com/tech/big-tech/article/327...
# 2     https://www.cnbc.com/2024/07/24/jim-cramer-exa...
# 3     https://www.benzinga.com/pressreleases/24/07/g...
# 4     https://cointelegraph.com/news/tiny-500gh-home...
# 5     https://www.zacks.com/stock/news/2308225/googl...
# 6     https://www.benzinga.com/general/24/07/3994357...
# 7     https://decrypt.co/241465/proton-wallet-launch...
# 8     https://www.fool.com/investing/2024/07/24/why-...
# 9                          https://consent.google.com/m
# 10    https://www.fool.com/data-news/2024/07/24/cme-...
# 11                         https://consent.google.com/m
# 12    https://www.benzinga.com/news/24/07/39941711/w...
# 13    https://www.fool.com/investing/2024/07/24/why-...
# 14    https://www.benzinga.com/general/gaming/24/07/...
# 15    https://www.business-standard.com/companies/ne...
# 16                         https://consent.google.com/m
# 17                         https://consent.google.com/m
# 18                         https://consent.google.com/m
# 19                         https://consent.google.com/m
# 20                         https://consent.google.com/m
# 21                         https://consent.google.com/m
# 22                         https://consent.google.com/m
# 23                         https://consent.google.com/m
# 24                         https://consent.google.com/m
# 25    https://www.benzinga.com/general/sports/24/07/...
# 26                         https://consent.google.com/m
# 27                         https://consent.google.com/m
# 28                         https://consent.google.com/m
# 29                         https://consent.google.com/m
# 30                         https://consent.google.com/m
# 31                         https://consent.google.com/m
# 32                         https://consent.google.com/m
# 33    https://www.benzinga.com/markets/equities/24/0...
# 34                         https://consent.google.com/m
# 35                         https://consent.google.com/m
# 36                         https://consent.google.com/m
# 37                         https://consent.google.com/m
# 38                         https://consent.google.com/m
# 39    https://www.cnbc.com/2024/07/24/renewable-ener...
# 40    https://www.fool.com/data-news/2024/07/24/alph...
# 41    https://www.benzinga.com/news/24/07/39938971/c...
# 42                         https://consent.google.com/m
# 43    https://www.benzinga.com/analyst-ratings/analy...
# 44                         https://consent.google.com/m
# 45                         https://consent.google.com/m
# 46    https://www.fool.com/earnings/call-transcripts...
# 47    https://www.fool.com/earnings/call-transcripts...
# 48    https://www.benzinga.com/markets/cryptocurrenc...
# 49    https://cointelegraph.com/news/polymarket-clin...
# Name: url, dtype: object

# %%
"""import nltk
from nltk.sentiment.vader import SentimentIntensityAnalyzer

# Initialize Vader's SentimentIntensityAnalyzer
analyzer = SentimentIntensityAnalyzer()

# Example text
text = "This movie was absolutely amazing! I would highly recommend it."

# Analyze sentiment
sentiment = analyzer.polarity_scores(text)

# Print sentiment scores
print(sentiment)"""
# Out:
# 'import nltk\nfrom nltk.sentiment.vader import SentimentIntensityAnalyzer\n\n# Initialize Vader\'s SentimentIntensityAnalyzer\nanalyzer = SentimentIntensityAnalyzer()\n\n# Example text\ntext = "This movie was absolutely amazing! I would highly recommend it."\n\n# Analyze sentiment\nsentiment = analyzer.polarity_scores(text)\n\n# Print sentiment scores\nprint(sentiment)'

# %%
summary_list=df['summary'].to_list()

# %%
import nltk

# %%
nltk.download('vader_lexicon')
# Out:
# [nltk_data] Downloading package vader_lexicon to /home/studio-lab-
# [nltk_data]     user/nltk_data...
# [nltk_data]   Package vader_lexicon is already up-to-date!
# True

# %%
import nltk
from nltk.sentiment.vader import SentimentIntensityAnalyzer
analyzer = SentimentIntensityAnalyzer()

sentiment_list=[]
for i in summary_list:
    temp=analyzer.polarity_scores(i)
    sentiment_list.append(temp)

# %%
sentiment_list
# Out:
# [{'neg': 0.033, 'neu': 0.826, 'pos': 0.141, 'compound': 0.7269},
#  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0},
#  {'neg': 0.119, 'neu': 0.881, 'pos': 0.0, 'compound': -0.4767},
#  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0},
#  {'neg': 0.121, 'neu': 0.669, 'pos': 0.209, 'compound': 0.2732},
#  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0},
#  {'neg': 0.092, 'neu': 0.833, 'pos': 0.074, 'compound': -0.2023},
#  {'neg': 0.0, 'neu': 0.793, 'pos': 0.207, 'compound': 0.5267},
#  {'neg': 0.0, 'neu': 0.763, 'pos': 0.237, 'compound': 0.4215},
#  {'neg': 0.0, 'neu': 0.903, 'pos': 0.097, 'compound': 0.1027},
#  {'neg': 0.0, 'neu': 0.604, 'pos': 0.396, 'compound': 0.7096},
#  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0},
#  {'neg': 0.103, 'neu': 0.742, 'pos': 0.155, 'compound': 0.3612},
#  {'neg': 0.0, 'neu': 0.782, 'pos': 0.218, 'compound': 0.5994},
#  {'neg': 0.0, 'neu': 0.949, 'pos': 0.051, 'compound': 0.34},
#  {'neg': 0.0, 'neu': 0.865, 'pos': 0.135, 'compound': 0.4522},
#  {'neg': 0.394, 'neu': 0.469, 'pos': 0.136, 'compound': -0.7579},
#  {'neg': 0.0, 'neu': 0.662, 'pos': 0.338, 'compound': 0.5574},
#  {'neg': 0.277, 'neu': 0.723, 'pos': 0.0, 'compound': -0.5574},
#  {'neg': 0.0, 'neu': 0.807, 'pos': 0.193, 'compound': 0.4767},
#  {'neg': 0.167, 'neu': 0.833, 'pos': 0.0, 'compound': -0.296},
#  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0},
#  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0},
#  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0},
#  {'neg': 0.0, 'neu': 0.833, 'pos': 0.167, 'compound': 0.34},
#  {'neg': 0.077, 'neu': 0.667, 'pos': 0.256, 'compound': 0.7906},
#  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0},
#  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0},
#  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0},
#  {'neg': 0.0, 'neu': 0.755, 'pos': 0.245, 'compound': 0.6369},
#  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0},
#  {'neg': 0.074, 'neu': 0.784, 'pos': 0.142, 'compound': 0.34},
#  {'neg': 0.333, 'neu': 0.667, 'pos': 0.0, 'compound': -0.7579},
#  {'neg': 0.065, 'neu': 0.79, 'pos': 0.145, 'compound': 0.6757},
#  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0},
#  {'neg': 0.0, 'neu': 0.838, 'pos': 0.162, 'compound': 0.4404},
#  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0},
#  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0},
#  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0},
#  {'neg': 0.0, 'neu': 0.922, 'pos': 0.078, 'compound': 0.1779},
#  {'neg': 0.0, 'neu': 0.82, 'pos': 0.18, 'compound': 0.5106},
#  {'neg': 0.052, 'neu': 0.9, 'pos': 0.047, 'compound': -0.0516},
#  {'neg': 0.121, 'neu': 0.879, 'pos': 0.0, 'compound': -0.1655},
#  {'neg': 0.0, 'neu': 0.749, 'pos': 0.251, 'compound': 0.886},
#  {'neg': 0.121, 'neu': 0.879, 'pos': 0.0, 'compound': -0.1655},
#  {'neg': 0.121, 'neu': 0.879, 'pos': 0.0, 'compound': -0.1655},
#  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0},
#  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0},
#  {'neg': 0.084, 'neu': 0.837, 'pos': 0.08, 'compound': -0.0516},
#  {'neg': 0.0, 'neu': 0.761, 'pos': 0.239, 'compound': 0.5267}]

# %%
compound_list=[]
for i in sentiment_list:
    temp=i.get('compound')
    compound_list.append(temp)
compound_list
# Out:
# [0.7269,
#  0.0,
#  -0.4767,
#  0.0,
#  0.2732,
#  0.0,
#  -0.2023,
#  0.5267,
#  0.4215,
#  0.1027,
#  0.7096,
#  0.0,
#  0.3612,
#  0.5994,
#  0.34,
#  0.4522,
#  -0.7579,
#  0.5574,
#  -0.5574,
#  0.4767,
#  -0.296,
#  0.0,
#  0.0,
#  0.0,
#  0.34,
#  0.7906,
#  0.0,
#  0.0,
#  0.0,
#  0.6369,
#  0.0,
#  0.34,
#  -0.7579,
#  0.6757,
#  0.0,
#  0.4404,
#  0.0,
#  0.0,
#  0.0,
#  0.1779,
#  0.5106,
#  -0.0516,
#  -0.1655,
#  0.886,
#  -0.1655,
#  -0.1655,
#  0.0,
#  0.0,
#  -0.0516,
#  0.5267]

# %%
df['overall_sentiment_score']
# Out:
# 0     0.314531
# 1     0.144264
# 2     0.039067
# 3     0.541221
# 4    -0.057454
# 5     0.207244
# 6     0.103121
# 7     0.087654
# 8     0.043837
# 9     0.086343
# 10    0.376996
# 11    0.086343
# 12    0.142465
# 13    0.182052
# 14    0.508850
# 15    0.356618
# 16    0.086343
# 17    0.086343
# 18    0.086343
# 19    0.086343
# 20    0.086343
# 21    0.086343
# 22    0.086343
# 23    0.086343
# 24    0.086343
# 25    0.360795
# 26    0.086343
# 27    0.086343
# 28    0.086343
# 29    0.086343
# 30    0.086343
# 31    0.086343
# 32    0.086343
# 33   -0.032187
# 34    0.086343
# 35    0.086343
# 36    0.086343
# 37    0.086343
# 38    0.086343
# 39    0.128916
# 40    0.253210
# 41   -0.060348
# 42    0.086343
# 43    0.254355
# 44    0.086343
# 45    0.086343
# 46    0.283085
# 47    0.283085
# 48   -0.106378
# 49    0.156543
# Name: overall_sentiment_score, dtype: float64

# %%
close_list
# Out:
# [168.68,
#  169.16,
#  174.37,
#  183.6,
#  183.35,
#  179.39,
#  179.22,
#  182.62,
#  185.5,
#  188.19,
#  186.78,
#  187.3,
#  192.66,
#  190.44,
#  190.48,
#  191.96,
#  187.39,
#  186.61,
#  184.49,
#  183.42,
#  186.86,
#  185.37,
#  185.58,
#  180.79,
#  180.26,
#  177.71,
#  176.45,
#  178.78,
#  178.37,
#  176.74,
#  179.56,
#  178.19,
#  176.63,
#  175.95,
#  178.35,
#  177.07,
#  175.13,
#  174.42,
#  173.96,
#  173.56,
#  177.4,
#  178.02,
#  176.33,
#  175.06,
#  178.0,
#  179.54,
#  178.46,
#  177.29,
#  175.43,
#  173.88,
#  171.93,
#  170.9,
#  170.29,
#  171.58,
#  171.16,
#  172.98,
#  169.83,
#  168.99,
#  168.46,
#  165.57,
#  164.64,
#  167.9,
#  173.69,
#  157.95,
#  161.1,
#  159.92,
#  157.95,
#  155.72,
#  157.46,
#  156.88,
#  156.0,
#  156.33,
#  159.19,
#  160.79,
#  157.66,
#  158.14,
#  156.14,
#  153.94,
#  151.94,
#  156.37,
#  155.87,
#  156.5,
#  152.26,
#  151.94,
#  151.7,
#  151.15,
#  151.77,
#  148.74,
#  149.68,
#  147.92,
#  148.48,
#  142.17,
#  144.34,
#  140.77,
#  139.62,
#  138.94,
#  136.29,
#  135.24,
#  132.56,
#  133.78]

# %%
time_list
# Out:
# ['2024-07-26',
#  '2024-07-25',
#  '2024-07-24',
#  '2024-07-23',
#  '2024-07-22',
#  '2024-07-19',
#  '2024-07-18',
#  '2024-07-17',
#  '2024-07-16',
#  '2024-07-15',
#  '2024-07-12',
#  '2024-07-11',
#  '2024-07-10',
#  '2024-07-09',
#  '2024-07-08',
#  '2024-07-05',
#  '2024-07-03',
#  '2024-07-02',
#  '2024-07-01',
#  '2024-06-28',
#  '2024-06-27',
#  '2024-06-26',
#  '2024-06-25',
#  '2024-06-24',
#  '2024-06-21',
#  '2024-06-20',
#  '2024-06-18',
#  '2024-06-17',
#  '2024-06-14',
#  '2024-06-13',
#  '2024-06-12',
#  '2024-06-11',
#  '2024-06-10',
#  '2024-06-07',
#  '2024-06-06',
#  '2024-06-05',
#  '2024-06-04',
#  '2024-06-03',
#  '2024-05-31',
#  '2024-05-30',
#  '2024-05-29',
#  '2024-05-28',
#  '2024-05-24',
#  '2024-05-23',
#  '2024-05-22',
#  '2024-05-21',
#  '2024-05-20',
#  '2024-05-17',
#  '2024-05-16',
#  '2024-05-15',
#  '2024-05-14',
#  '2024-05-13',
#  '2024-05-10',
#  '2024-05-09',
#  '2024-05-08',
#  '2024-05-07',
#  '2024-05-06',
#  '2024-05-03',
#  '2024-05-02',
#  '2024-05-01',
#  '2024-04-30',
#  '2024-04-29',
#  '2024-04-26',
#  '2024-04-25',
#  '2024-04-24',
#  '2024-04-23',
#  '2024-04-22',
#  '2024-04-19',
#  '2024-04-18',
#  '2024-04-17',
#  '2024-04-16',
#  '2024-04-15',
#  '2024-04-12',
#  '2024-04-11',
#  '2024-04-10',
#  '2024-04-09',
#  '2024-04-08',
#  '2024-04-05',
#  '2024-04-04',
#  '2024-04-03',
#  '2024-04-02',
#  '2024-04-01',
#  '2024-03-28',
#  '2024-03-27',
#  '2024-03-26',
#  '2024-03-25',
#  '2024-03-22',
#  '2024-03-21',
#  '2024-03-20',
#  '2024-03-19',
#  '2024-03-18',
#  '2024-03-15',
#  '2024-03-14',
#  '2024-03-13',
#  '2024-03-12',
#  '2024-03-11',
#  '2024-03-08',
#  '2024-03-07',
#  '2024-03-06',
#  '2024-03-05']

# %%
from matplotlib import pyplot as plt
from matplotlib import dates
converted_dates = dates.datestr2num(time_list)
print(converted_dates)

# Assuming close_list and compound_list are defined and contain numerical data

plt.plot(converted_dates, close_list)
plt.xlabel('Dates')  # Add x-axis label
plt.ylabel('Close list')  # Add y-axis label
plt.title('Scatter Plot of Close and date Values')  # Add title
plt.show()
# Out:
# [19930. 19929. 19928. 19927. 19926. 19923. 19922. 19921. 19920. 19919.
#  19916. 19915. 19914. 19913. 19912. 19909. 19907. 19906. 19905. 19902.
#  19901. 19900. 19899. 19898. 19895. 19894. 19892. 19891. 19888. 19887.
#  19886. 19885. 19884. 19881. 19880. 19879. 19878. 19877. 19874. 19873.
#  19872. 19871. 19867. 19866. 19865. 19864. 19863. 19860. 19859. 19858.
#  19857. 19856. 19853. 19852. 19851. 19850. 19849. 19846. 19845. 19844.
#  19843. 19842. 19839. 19838. 19837. 19836. 19835. 19832. 19831. 19830.
#  19829. 19828. 19825. 19824. 19823. 19822. 19821. 19818. 19817. 19816.
#  19815. 19814. 19810. 19809. 19808. 19807. 19804. 19803. 19802. 19801.
#  19800. 19797. 19796. 19795. 19794. 19793. 19790. 19789. 19788. 19787.]

# %%
"""# importing pandas as pd
import pandas as pd


# list of name, degree, score
nme = ["aparna", "pankaj", "sudhir", "Geeku"]
deg = ["MBA", "BCA", "M.Tech", "MBA"]
scr = [90, 40, 80, 98]

# dictionary of lists
dict = {'name': nme, 'degree': deg, 'score': scr}

df = pd.DataFrame(dict)

# saving the dataframe
df.to_csv('GFG.csv')"""
# Out:
# '# importing pandas as pd\nimport pandas as pd\n\n\n# list of name, degree, score\nnme = ["aparna", "pankaj", "sudhir", "Geeku"]\ndeg = ["MBA", "BCA", "M.Tech", "MBA"]\nscr = [90, 40, 80, 98]\n\n# dictionary of lists\ndict = {\'name\': nme, \'degree\': deg, \'score\': scr}\n\ndf = pd.DataFrame(dict)\n\n# saving the dataframe\ndf.to_csv(\'GFG.csv\')'

# %%
#1. data processing
#2. get the data of opening and closing rate
#3. get news data of that particular date
#4. perform sentiment analysis on new data
#5. get sentiment score
#6. get the avg of compound data
#7. test regression model using stock and avg data
#8. compare with stock prices of next day
#9. find loss
#10. train until model reaches required accuracy
